# %% [markdown]
# <a href="https://colab.research.google.com/github/Mallick223/Mallick223/blob/main/Ml_exp-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Math
import math
sqrt_value=math.sqrt(25)
print(f"Square root of 25:{sqrt_value:.2f}")
factorial_value=math.factorial(5)
print(f"Factorial of 5:{factorial_value:}")
angle_radians=math.radians(30)
sine_value=math.sin(angle_radians)
print(f"Sine of 30 degrees:{sine_value:.2f}")

#numPy
import numpy as np
arr1d=np.array([1,2,3])
print(f"1D Array:{arr1d}")
arr2d=np.array([[1,2,3],[4,5,6]])
print(f"2D array:{arr2d}")

#SciPy
import scipy.optimize as opt
def objective(x):
  return x[0]**2+x[1]**2
  result=opt.minimize(objective,[1,1])
  print("Optimal solution:",result.x)
from scipy.integrate import quad
def integrand(x):
  return x**2
area,error=quad(integrand,0,2)
print(f"Integral Result :{area:2f}")
# Out:
# Square root of 25:5.00
# Factorial of 5:120
# Sine of 30 degrees:0.50
# 1D Array:[1 2 3]
# 2D array:[[1 2 3]
#  [4 5 6]]
# Integral Result :  4.666666666666667
