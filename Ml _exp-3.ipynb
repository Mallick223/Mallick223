# %% [markdown]
# <a href="https://colab.research.google.com/github/Mallick223/Mallick223/blob/main/Ml%20_exp-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pandas
import pandas as pd
data={'Name':['Alice','Bob','Charlie'],'Age ':[25,30,22]}
df=pd.DataFrame(data)
print(df)

#matplotlib
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,15,7,20,21]
plt.plot(x,y,marker='o',label='sales')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.title('Monthly Sales')
plt.grid(True)
plt.legend()
plt.show()
# Out:
#       Name  Age
# 0    Alice    25
# 1      Bob    30
# 2  Charlie    22
