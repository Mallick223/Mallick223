# %% [markdown]
# <a href="https://colab.research.google.com/github/Mallick223/Mallick223/blob/main/exp4_i.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
x=np.array([[1],[2],[3],[4],[5]])
y=np.array([2,4,5,4,6])
reg=LinearRegression().fit(x,y)
slope=reg.coef_[0]
intercept=reg.intercept_
print(f"Slope (coefficient):{slope:.2f}")
print("Intercept:",intercept)
new_x=np.array([[6]])
predicted_y=reg.predict(new_x)
print(f"predicted value for x=6:{predicted_y[0]:.2f}")
plt.scatter(x,y,color='blue',label='data points')
plt.plot(x,reg.predict(x),color='red',label='regression line')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Simple Linear Regression')
plt.legend()
plt.show()
# Out:
# Slope (coefficient):0.80
# Intercept: 1.7999999999999998
# predicted value for x=6:6.60
